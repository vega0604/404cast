# %%
import pandas as pd

# Load the major crime CSV file
df = pd.read_csv('../major_crime_data.csv')

# Display the first few rows
df.head()
# Out:
#    OBJECTID EVENT_UNIQUE_ID          REPORT_DATE             OCC_DATE  \
# 0         1  GO-20141637937  1/1/2014 5:00:00 AM  3/1/2012 5:00:00 AM
# 1         2  GO-20141260793  1/1/2014 5:00:00 AM  1/1/2014 5:00:00 AM
# 2         3  GO-20141259834  1/1/2014 5:00:00 AM  1/1/2014 5:00:00 AM
# 3         4  GO-20141260264  1/1/2014 5:00:00 AM  1/1/2014 5:00:00 AM
# 4         5  GO-20141260264  1/1/2014 5:00:00 AM  1/1/2014 5:00:00 AM
#
#    REPORT_YEAR REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  \
# 0         2014      January           1           1  Wednesday            16
# 1         2014      January           1           1  Wednesday             3
# 2         2014      January           1           1  Wednesday             0
# 3         2014      January           1           1  Wednesday             1
# 4         2014      January           1           1  Wednesday             1
#
#    ...              OFFENCE MCI_CATEGORY  HOOD_158          NEIGHBOURHOOD_158  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430614 entries, 0 to 430613
# Data columns (total 31 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   OBJECTID           430614 non-null  int64
#  1   EVENT_UNIQUE_ID    430614 non-null  object
#  2   REPORT_DATE        430614 non-null  object
#  3   OCC_DATE           430614 non-null  object
#  4   REPORT_YEAR        430614 non-null  int64
#  5   REPORT_MONTH       430614 non-null  object
#  6   REPORT_DAY         430614 non-null  int64
#  7   REPORT_DOY         430614 non-null  int64
#  8   REPORT_DOW         430614 non-null  object
#  9   REPORT_HOUR        430614 non-null  int64
#  10  OCC_YEAR           430469 non-null  float64
#  11  OCC_MONTH          430469 non-null  object
#  12  OCC_DAY            430469 non-null  float64
#  13  OCC_DOY            430469 non-null  float64
#  14  OCC_DOW            430469 non-null  object
# ...
